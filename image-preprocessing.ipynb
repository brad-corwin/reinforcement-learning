# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('00_sample_image.png')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
grey_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(grey_image, cmap='gray')
plt.show()

# %%
#cv2.imshow('image', grey_image)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
#cv2.imwrite('images/01_grey_sample_image.png',grey_image)

# %%
#import pyautogui
#image = pyautogui.screenshot()
#image = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)
#plt.imshow(image)
#plt.show()

# %%
import pygetwindow as gw

# %%
emu_window = gw.getWindowsWithTitle('Nestopia')[0]

# %%
tl = emu_window.topleft
tl
# Out:
# Point(x=790, y=220)

# %%
br = emu_window.bottomright
br
# Out:
# Point(x=1578, y=978)

# %%
# note must be on main window
from PIL import ImageGrab

# Nestopia - View->Screen Size->3x
# Screen 1080p might need to adjust
MENU_HEIGHT=70
GROUND_TRIM=75
LEFT_TRIM=10
RIGHT_TRIM=10

image = ImageGrab.grab(bbox=(tl[0]+LEFT_TRIM, tl[1]+MENU_HEIGHT, br[0]-RIGHT_TRIM, br[1]-GROUND_TRIM))
image
# Out:
# <PIL.Image.Image image mode=RGB size=768x613 at 0x27E9F4C23C8>

# %%
image.convert('L')
# Out:
# <PIL.Image.Image image mode=L size=768x613 at 0x27E9F2F1748>

# %%
env = np.array(image.convert('L'))
env
# Out:
# array([[157, 157, 157, ..., 157, 157, 157],
#        [157, 157, 157, ..., 157, 157, 157],
#        [157, 157, 157, ..., 157, 157, 157],
#        ...,
#        [218, 218, 218, ...,   0,   0,   0],
#        [218, 218, 218, ...,   0,   0,   0],
#        [218, 218, 218, ...,   0,   0,   0]], dtype=uint8)
